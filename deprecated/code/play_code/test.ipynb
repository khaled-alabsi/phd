# %%
from test_code import print_hello

# %%
print_hello()
# Out:
# Hello from test222.py

# %%
some_variable = 42

# %%
import importlib
import test_code
importlib.reload(test_code)
from test_code import print_hello
print_hello()
# Out:
# Hello, qwerqwerqwer!
# Hello from test222eaerer.py

# %%
some_variable
# Out:
# 42

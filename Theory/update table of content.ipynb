# %% [markdown]
# # This tools will create/update Table of Contents file
#
# ## Install requierment
# ### on mac
# -  install homenrew
#     ```cmd
#     /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
#     ````
# - Install python 3
#     ```cmd
#     brew install python@3.12
#     ````
# - Select python interperter in vs code and create virtual env and install `requierment.txt`

# %%
from Resources.tools import fix_latex, combine_md_files, generate_content_files, create_main_content_file, create_directory_structure_md

input_folder = "./"
fix_latex(
    path=input_folder,  # Replace with your folder path
    show_changes=True,  # Set to True to log changes
    overwrite_original_file=True,  # Set to True to overwrite original files
)

generate_content_files("./Research")
create_main_content_file()

create_directory_structure_md()
# Out:
# Processing path: ./
# Processing folder: ./
# Processing file: ./Project Structure.md
# Processing file: ./Table of content.md
# Processing file: ./Roadmap.md
# Processing folder: ./Research
# Processing file: ./Research/content.md
# Processing folder: ./Research/004- Relevent Distrubtions
# Processing file: ./Research/004- Relevent Distrubtions/content.md
# Processing folder: ./Research/005- Benchmarking
# Processing file: ./Research/005- Benchmarking/001- ARL.md
# Processing file: ./Research/005- Benchmarking/Metrics summary 2.md
# Processing file: ./Research/005- Benchmarking/MSPC Benchmarking Data and Methods.md
# Processing file: ./Research/005- Benchmarking/003- MDRL.md
# Processing file: ./Research/005- Benchmarking/content.md
# Processing file: ./Research/005- Benchmarking/ARL1_FDR_FAR.md
# Processing file: ./Research/005- Benchmarking/002- SDRL.md
# Processing file: ./Research/005- Benchmarking/005- Detection Rate.md
# ...
